# %% [markdown]
# <a href="https://colab.research.google.com/github/ardaffa2000/Image-Classification-1-Assignment/blob/main/Tugas_14B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
  #frek = frekuensi (MHz)
  #tipe = urban, suburban, open
  #ht = tinggi tower (meter)
  #hr = tinggi user (meter)
  #d = jarak (meter)
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
NtL = lambda x: 10*np.log10(x)

# %%
LtN = lambda x: 10**(x/10)

# %%
def dt(PTX,Lp,GTX,GRX):
  y = NtL(PTX)
  Prx = y - Lp + GTX + GRX
  Prn = LtN(Prx)
  return Prn

# %%
f=1800 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='suburban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
b=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='open'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
c=np.random.randint(dmin,dmax,N)

# %%
Lpurban=cos(f,loc,tower,user,a)

# %%
dturban=dt(PTX,LpUrban,GTX,GRX)

# %%
Lpsuburban=cos(f,loc,tower,user,b)

# %%
dtsuburban=dt(PTX,Lpsuburban,GTX,GRX)

# %%
Lpopen=cos(f,loc,tower,user,c)

# %%
dtopen=dt(PTX,Lpopen,GTX,GRX)

# %%
plt.figure()
plt.plot(a,dturban,'r-o',label='urban')
plt.plot(b,dtsuburban,'g-x',label='suburban')
plt.plot(c,dtopen,'b-+',label='open')

# %%
a_sort=a[np.argsort(a)]
Urban_sort=dturban[np.argsort(a)]

b_sort=b[np.argsort(b)]
suburban_sort=dtsuburban[np.argsort(b)]

c_sort=c[np.argsort(c)]
open_sort=dtopen[np.argsort(c)]

# %%
plt.figure()
plt.plot(a_sort,Urban_sort,'r-o',label='urban')
plt.plot(b_sort,suburban_sort,'g-x',label='suburban')
plt.plot(c_sort,open_sort,'b-+',label='open')
plt.legend()
plt.title('Grafik daya terima Pada 3 Area Berbeda di Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('daya terima')
plt.show()

# %%
f=700 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
a=np.random.randint(dmin,dmax,N)

# %%
f=900 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
a=np.random.randint(dmin,dmax,N)

# %%
Lp700=cos(f,loc,tower,user,a)

# %%
dt700=dt(PTX,LpUrban,GTX,GRX)

# %%
Lp900=cos(f,loc,tower,user,b)

# %%
dt900=dt(PTX,Lpsuburban,GTX,GRX)

# %%
Lp1800=cos(f,loc,tower,user,c)

# %%
dt1800=dt(PTX,Lpopen,GTX,GRX)

# %%
plt.figure()
plt.plot(a,dt700,'r-o',label='urban')
plt.plot(b,dt900,'g-x',label='suburban')
plt.plot(c,dt1800,'b-+',label='open')

# %%
a_sort=a[np.argsort(a)]
Urban_sort=dt700[np.argsort(a)]

b_sort=b[np.argsort(b)]
suburban_sort=dt900[np.argsort(b)]

c_sort=c[np.argsort(c)]
open_sort=dt1800[np.argsort(c)]

# %%
plt.figure()
plt.plot(a_sort,Urban_sort,'r-o',label='urban')
plt.plot(b_sort,suburban_sort,'g-x',label='suburban')
plt.plot(c_sort,open_sort,'b-+',label='open')
plt.legend()
plt.title('Grafik daya terima Pada 3 Area Berbeda di Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('daya terima')
plt.show()

# %%
def snr(Prx,BW):
  No = -174 + 10*np.log10(BW)
  Nn = LtN(No)
  SNR = Prx/Nn
  return SNR

# %%
f=1800 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='suburban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW-5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='open'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
Lpurban=cos(f,loc,tower,user,a)

# %%
PRXurban=dturban

# %%
snrurban=snr(PRXurban,BW)

# %%
Lpsuburban=cos(f,loc,tower,user,b)

# %%
PRXsuburban=dtsuburban

# %%
snrs=snr(PRXsuburban,BW)

# %%
Lpopen=cos(f,loc,tower,user,c)

# %%
PRXopen=dtopen

# %%
snropen=snr(PRXopen,BW)

# %%
plt.figure()
plt.plot(a,snrurban,'r-o',label='urban')
plt.plot(b,snrs,'g-x',label='suburban')
plt.plot(c,snropen,'b-+',label='open')

# %%
a_sort=a[np.argsort(a)]
Urban_sort=snrurban[np.argsort(a)]

b_sort=b[np.argsort(b)]
suburban_sort=snrs[np.argsort(b)]

c_sort=c[np.argsort(c)]
open_sort=dt1800[np.argsort(c)]

# %%
plt.figure()
plt.plot(a_sort,Urban_sort,'r-o',label='urban')
plt.plot(b_sort,suburban_sort,'g-x',label='suburban')
plt.plot(c_sort,open_sort,'b-+',label='open')
plt.legend()
plt.title('Grafik SNR Pada 3 Area Berbeda di Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('SNR')
plt.show()

# %%
f=700 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=900 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW-5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
Lp700=cos(f,loc,tower,user,a)

# %%
PRX700=dturban

# %%
snr700=snr(PRX700,BW)

# %%
Lp900=cos(f,loc,tower,user,b)

# %%
PRX900=dt900

# %%
snr900=snr(PRX900,BW)

# %%
Lp1800=cos(f,loc,tower,user,c)

# %%
PRX1800=dt1800

# %%
snr1800=snr(PRX1800,BW)

# %%
plt.figure()
plt.plot(a,snr700,'r-o',label='urban')
plt.plot(b,snr900,'g-x',label='suburban')
plt.plot(c,snr1800,'b-+',label='open')

# %%
a_sort=a[np.argsort(a)]
Urban_sort=snr700[np.argsort(a)]

b_sort=b[np.argsort(b)]
suburban_sort=snr900[np.argsort(b)]

c_sort=c[np.argsort(c)]
open_sort=snr1800[np.argsort(c)]

# %%
plt.figure()
plt.plot(a_sort,Urban_sort,'r-o',label='urban')
plt.plot(b_sort,suburban_sort,'g-x',label='suburban')
plt.plot(c_sort,open_sort,'b-+',label='open')
plt.legend()
plt.title('Grafik SNR Pada 3 frekuensi Berbeda di area urban ')
plt.xlabel('Jarak (m)')
plt.ylabel('snr')
plt.show()

# %%
def Sc(SNR,BW):
  sc = BW * np.log2(1+SNR)
  return sc

# %%
f=1800 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='suburban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='open'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
Lpurban=cos(f,loc,tower,user,a)

# %%
PRXurban=dturban

# %%
snrurban=snr(PRXurban,BW)

# %%
scurban=Sc(snrurban,BW)

# %%
Lpsuburban=cos(f,loc,tower,user,b)

# %%
PRXsuburban=dtsuburban

# %%
snrs=snr(PRXsuburban,BW)

# %%
scsub=Sc(snrs,BW)

# %%
Lpopen=cos(f,loc,tower,user,c)

# %%
PRXopen=dtopen

# %%
snropen=snr(PRXopen,BW)

# %%
scopen=Sc(snropen,BW)

# %%
plt.figure()
plt.plot(a,scurban,'r-o',label='urban')
plt.plot(b,scsub,'g-x',label='suburban')
plt.plot(c,scopen,'b-+',label='open')

# %%
a_sort=a[np.argsort(a)]
Urban_sort=scurban[np.argsort(a)]

b_sort=b[np.argsort(b)]
suburban_sort=scsub[np.argsort(b)]

c_sort=c[np.argsort(c)]
open_sort=scopen[np.argsort(c)]

# %%
plt.figure()
plt.plot(a_sort,Urban_sort,'r-o',label='urban')
plt.plot(b_sort,suburban_sort,'g-x',label='suburban')
plt.plot(c_sort,open_sort,'b-+',label='open')
plt.legend()
plt.title('Grafik bandwidth Pada 3 frekuensi Berbeda di area urban ')
plt.xlabel('Jarak (m)')
plt.ylabel('snr')
plt.show()

# %%
f=700 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=900 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW-5000000
a=np.random.randint(dmin,dmax,N)

# %%
f=1800 #MHz
loc='urban'
tower=80 #m
user=1.5 #m
dmin=300 #m
dmax=1000 #m
N=200 #titik
GTX=10
GRX=5
PTX=30
BW=5000000
a=np.random.randint(dmin,dmax,N)

# %%
Lpurban=cos(f,loc,tower,user,a)

# %%
PRX700=dt700

# %%
snr700=snr(PRX700,BW)

# %%
sc700=Sc(snr700,BW)

# %%
Lp900=cos(f,loc,tower,user,b)

# %%
PRX900=dt900

# %%
snr900=snr(PRX900,BW)

# %%
sc900=Sc(snr900,BW)

# %%
Lp1800=cos(f,loc,tower,user,c)

# %%
PRX1800=dt1800

# %%
snr1800=snr(PRX1800,BW)

# %%
sc1800=Sc(snr1800,BW)

# %%
plt.figure()
plt.plot(a,sc700,'r-o',label='urban')
plt.plot(b,sc900,'g-x',label='suburban')
plt.plot(c,sc1800,'b-+',label='open')

# %%
a_sort=a[np.argsort(a)]
Urban_sort=sc700[np.argsort(a)]

b_sort=b[np.argsort(b)]
suburban_sort=sc900[np.argsort(b)]

c_sort=c[np.argsort(c)]
open_sort=sc1800[np.argsort(c)]

# %%
plt.figure()
plt.plot(a_sort,Urban_sort,'r-o',label='urban')
plt.plot(b_sort,suburban_sort,'g-x',label='suburban')
plt.plot(c_sort,open_sort,'b-+',label='open')
plt.legend()
plt.title('Grafik Kapasitas selular Pada 3 frekuensi Berbeda di area urban ')
plt.xlabel('Jarak (m)')
plt.ylabel('snr')
plt.show()
